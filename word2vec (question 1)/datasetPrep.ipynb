# %% [markdown]
# # Part 0 Dataset Preparation

# %% [markdown]
# Exploratory ipynb

# %%
# %pip install datasets
# Out:
# Requirement already satisfied: datasets in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (3.0.2)
# Requirement already satisfied: packaging in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (21.0)
# Requirement already satisfied: xxhash in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (0.26.1)
# Requirement already satisfied: numpy>=1.17 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (1.20.3)
# Requirement already satisfied: aiohttp in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (6.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (2024.9.0)
# Requirement already satisfied: pandas in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (1.3.4)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: filelock in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (3.3.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (1.26.7)
# Requirement already satisfied: propcache>=0.2.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
from datasets import load_dataset
dataset = load_dataset("rotten_tomatoes")
train_dataset = dataset['train'] 
validation_dataset = dataset['validation']
test_dataset = dataset['test']

# %%
from gensim.utils import simple_preprocess

# preprocess
sentences = []
for line in train_dataset['text']:
    sentence = simple_preprocess(line)
    sentences.append(sentence)

# %% [markdown]
# # Part 1 Preparing Word Embeddings

# %%
# %pip install gensim
import gensim
from gensim.models import Word2Vec
# Out:
# Requirement already satisfied: gensim in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (4.3.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from gensim) (7.0.5)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.20.3)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from gensim) (1.7.1)
# Requirement already satisfied: wrapt in /Users/phoebe/opt/anaconda3/lib/python3.9/site-packages (from smart-open>=1.8.1->gensim) (1.12.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim.downloader as api
# wv = api.load('word2vec-google-news-300')
# this glove model gives fewer OOV (1938 vs ~2680) but it has a smaller vocab size so idk what's up
wv = api.load('glove-wiki-gigaword-300')

# %%
vocabulary = []
oov = []
for sentence in sentences:
    for word in sentence:
        if word in wv:
            if word not in vocabulary:
                vocabulary.append(word)
        else:
            if word not in oov:
                oov.append(word)

# %%
print(len(oov))
print(oov)

print(len(vocabulary))
print(vocabulary)
# Out:
# 580
# ['wisegirls', 'enrapturing', 'compleja', 'retadora', 'orquídeas', 'originalidad', 'suspenser', 'obviation', 'gorefests', 'waydowntown', 'makmalbaf', 'exhilarate', 'nuttgens', 'petin', 'provocatuers', 'jirí', 'hubac', 'shapelessly', 'addessi', 'seldahl', 'wollter', 'mullinski', 'avventura', 'needn', 'narcotizing', 'precollegiate', 'sparklingly', 'superlarge', 'destinees', 'margolo', 'dominatrixes', 'scuzbag', 'idoosyncratic', 'flatula', 'denlopp', 'updatings', 'watstein', 'sappier', 'condensada', 'divertida', 'visualmente', 'entretenida', 'sorprenderá', 'exporing', 'capturou', 'sarcástica', 'demencial', 'predecesora', 'complejos', 'cadness', 'shagster', 'powaqqatsi', 'policiales', 'últimos', 'kaputschnik', 'kickass', 'travil', 'splittingly', 'aborbing', 'monkeyfun', 'bierbichler', 'crummles', 'bustingly', 'stultifyingly', 'deutchland', 'datedness', 'inhospitability', 'næs', 'hastier', 'estava', 'existência', 'papai', 'fato', 'inquestionável', 'talancón', 'drippiness', 'oesn', 'montias', 'hotdogging', 'stumblings', 'birot', 'apesar', 'consegue', 'entreter', 'recoing', 'bizzarre', 'alientation', 'sogginess', 'mollà', 'involvingly', 'wifty', 'gerbosi', 'stuffiest', 'timewaster', 'strafings', 'debuter', 'histo', 'contando', 'premissa', 'mergulha', 'culminando', 'desfecho', 'certamente', 'memória', 'soaringly', 'entretiene', 'outgag', 'pulpiness', 'haphazardness', 'kibbitzes', 'auteil', 'cineasts', 'intacto', 'unconned', 'crappola', 'koshashvili', 'jaglomized', 'fizzability', 'sytle', 'decasia', 'stoppingly', 'choquart', 'espectáculo', 'digno', 'contemplarse', 'soberbio', 'montaje', 'colosal', 'universos', 'complementares', 'igualmente', 'fascinantes', 'captivatingly', 'fillm', 'unforgivingly', 'unreligious', 'anteing', 'marcken', 'mouglalis', 'everlyn', 'animé', 'kosashvili', 'idemoto', 'ozpetek', 'komediant', 'cinemantic', 'efteriades', 'narcotized', 'graças', 'às', 'interações', 'personagens', 'perseguição', 'também', 'estudo', 'contructed', 'volletta', 'whimsicality', 'uncinematic', 'corniest', 'unslick', 'uplifter', 'blighter', 'naturedness', 'hjelje', 'gaï', 'masterpeice', 'enternecedora', 'profundamente', 'sincera', 'románticas', 'delicia', 'bjorkness', 'runteldat', 'cletis', 'musclefest', 'líquido', 'incoloro', 'elemento', 'achronological', 'copmovieland', 'sheerly', 'oídos', 'movilizador', 'enfrentados', 'deseos', 'miedos', 'prejuicios', 'engaña', 'enfrentará', 'disfrutable', 'prescinde', 'patriotero', 'manipulador', 'rintarô', 'kahlories', 'logra', 'desarrollarse', 'pretenciosas', 'resultan', 'truncheoning', 'claustrophic', 'hitchcockianism', 'chabrolian', 'gooeyness', 'crowdpleaser', 'espite', 'pincel', 'retrata', 'constatação', 'realidade', 'beseechingly', 'cativante', 'representando', 'direção', 'contrária', 'evolução', 'musicais', 'accomodates', 'cannier', 'estupendamente', 'actuada', 'sumamente', 'emotiva', 'fílmica', 'hellstenius', 'suspeito', 'ganha', 'funcionar', 'esfera', 'feardotcom', 'janklowicz', 'democracie', 'revigorates', 'qutting', 'luvvies', 'bergmanesque', 'snazziness', 'nohe', 'verete', 'diciness', 'colonics', 'outré', 'shmear', 'bornin', 'plaintiveness', 'unemotive', 'steinis', 'swordfights', 'dooper', 'adorability', 'materalism', 'unhibited', 'japanimator', 'achival', 'flakeball', 'qatsi', 'atreve', 'atacar', 'atacarse', 'duración', 'precisa', 'grandiosa', 'conmovedora', 'têm', 'início', 'saímos', 'começamos', 'acabamos', 'então', 'sinais', 'desaponta', 'hadn', 'unfakable', 'dreadfulness', 'marveilleux', 'heremakono', 'hotsies', 'preocupar', 'criar', 'melodramáticos', 'pianista', 'emocionante', 'obligada', 'impotentes', 'daneses', 'camareras', 'italianas', 'desee', 'expresar', 'surehanded', 'recurre', 'actuación', 'perdona', 'guión', 'mibii', 'shimmeringly', 'frissons', 'convencional', 'narrativa', 'quizá', 'arriesgado', 'próprio', 'abandone', 'paródia', 'utilizar', 'mesmos', 'clichês', 'havia', 'satirizado', 'nonethnic', 'dysfunctionally', 'vulakoro', 'ourside', 'goombah', 'dudsville', 'equlibrium', ' ...
# 15708
# ['the', 'rock', 'is', 'destined', 'to', 'be', 'st', 'century', 'new', 'conan', 'and', 'that', 'he', 'going', 'make', 'splash', 'even', 'greater', 'than', 'arnold', 'schwarzenegger', 'jean', 'claud', 'van', 'damme', 'or', 'steven', 'segal', 'gorgeously', 'elaborate', 'continuation', 'of', 'lord', 'rings', 'trilogy', 'so', 'huge', 'column', 'words', 'cannot', 'adequately', 'describe', 'co', 'writer', 'director', 'peter', 'jackson', 'expanded', 'vision', 'tolkien', 'middle', 'earth', 'effective', 'but', 'too', 'tepid', 'biopic', 'if', 'you', 'sometimes', 'like', 'go', 'movies', 'have', 'fun', 'wasabi', 'good', 'place', 'start', 'emerges', 'as', 'something', 'rare', 'an', 'issue', 'movie', 'honest', 'keenly', 'observed', 'it', 'doesn', 'feel', 'one', 'film', 'provides', 'some', 'great', 'insight', 'into', 'neurotic', 'mindset', 'all', 'comics', 'those', 'who', 'reached', 'absolute', 'top', 'game', 'offers', 'combination', 'entertainment', 'education', 'perhaps', 'no', 'picture', 'ever', 'made', 'has', 'more', 'literally', 'showed', 'road', 'hell', 'paved', 'with', 'intentions', 'steers', 'turns', 'in', 'snappy', 'screenplay', 'curls', 'at', 'edges', 'clever', 'want', 'hate', 'somehow', 'pulls', 'off', 'take', 'care', 'my', 'cat', 'refreshingly', 'different', 'slice', 'asian', 'cinema', 'this', 'well', 'worth', 'seeing', 'talking', 'singing', 'heads', 'what', 'really', 'surprises', 'about', 'its', 'low', 'key', 'quality', 'genuine', 'tenderness', 'wendigo', 'why', 'we', 'fed', 'through', 'eye', 'heart', 'mind', 'greatest', 'family', 'oriented', 'fantasy', 'adventure', 'ultimately', 'ponders', 'reasons', 'need', 'stories', 'much', 'utterly', 'compelling', 'wrote', 'which', 'reputation', 'most', 'famous', 'author', 'lived', 'comes', 'question', 'illuminating', 'overly', 'talky', 'documentary', 'masterpiece', 'four', 'years', 'making', 'ripe', 'beauty', 'will', 'tempt', 'willing', 'probe', 'inscrutable', 'mysteries', 'breath', 'fresh', 'air', 'true', 'sophistication', 'thoughtful', 'provocative', 'insistently', 'humanizing', 'cast', 'includes', 'actors', 'working', 'independent', 'lovely', 'amazing', 'involves', 'us', 'because', 'incisive', 'bleakly', 'amusing', 'how', 'our', 'lives', 'disturbing', 'frighteningly', 'evocative', 'assembly', 'imagery', 'hypnotic', 'music', 'composed', 'by', 'philip', 'glass', 'not', 'for', 'everyone', 'whom', 'connect', 'nice', 'departure', 'from', 'standard', 'moviegoing', 'fare', 'scores', 'few', 'points', 'doing', 'does', 'dedicated', 'hearted', 'professionalism', 'occasionally', 'melodramatic', 'also', 'extremely', 'spiderman', 'rocks', 'idealistic', 'love', 'story', 'brings', 'out', 'latent', 'year', 'old', 'romantic', 'minutes', 'treasure', 'planet', 'maintains', 'brisk', 'pace', 'races', 'familiar', 'however', 'lacks', 'grandeur', 'epic', 'often', 'associated', 'stevenson', 'tale', 'earlier', 'disney', 'efforts', 'helps', 'lil', 'bow', 'wow', 'tones', 'down', 'his', 'pint', 'sized', 'gangsta', 'act', 'play', 'someone', 'resembles', 'real', 'kid', 'guaranteed', 'move', 'anyone', 'shook', 'rattled', 'rolled', 'masterful', 'master', 'filmmaker', 'unique', 'deceptive', 'grimness', 'fatalist', 'worldview', 'light', 'cute', 'forgettable', 'there', 'way', 'effectively', 'teach', 'kids', 'dangers', 'drugs', 'think', 'projects', 'unfortunately', 'rated', 'paid', 'while', 'would', 'easy', 'give', 'crush', 'title', 'two', 'weddings', 'funeral', 'far', 'any', 'hugh', 'grant', 'whimsy', 'though', 'everything', 'might', 'literate', 'smart', 'never', 'took', 'always', 'seemed', 'static', 'cantet', 'perfectly', 'captures', 'hotel', 'lobbies', 'lane', 'highways', 'roadside', 'cafes', 'permeate', 'vincent', 'days', 'ms', 'fulford', 'wierzbicki', 'almost', 'spooky', 'her', 'sulky', 'calculating', 'lolita', 'turn', 'means', 'best', 'work', 'laissez', 'passer', 'distinguished', 'distinctive', 'effort', 'bona', 'fide', 'fascinating', 'replete', 'rewards', 'had', 'reap', 'them', 'bond', 'outings', 'recent', 'stunts', ' ...

# %%
# create a weight matrix for words in training docs
embedding_matrix = np.zeros((len(vocabulary), 300))
embedding_dict = {}

for i in range(len(vocabulary)):
    embedding_vector = wv[vocabulary[i]]
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
    embedding_dict[vocabulary[i]] = embedding_vector

# %%
print(embedding_matrix)
# Out:
# [[ 0.04656     0.21318001 -0.0074364  ...  0.0090611  -0.20988999
#    0.053913  ]
#  [-0.14924     0.021244   -0.34240001 ...  0.64679998 -0.37239
#   -0.085055  ]
#  [-0.1749      0.22956     0.24924    ... -0.24131    -0.40402001
#    0.054744  ]
#  ...
#  [ 0.33013001  0.47231999  0.11104    ...  0.43649    -0.31005001
#    0.12175   ]
#  [ 0.28295001  0.059428    0.12142    ... -0.24597999 -0.24743
#   -0.46906   ]
#  [ 0.30191001  0.095044    0.68882    ...  0.23462     0.044753
#   -0.83178002]]

# %%
# save dictionary as file. get embedding of a word by accessing embedding_dict[word]
np.save('embeddings.npy', embedding_dict)

# %%
# sample code for how to load and read file
read_dictionary = np.load('embeddings.npy',allow_pickle='TRUE').item()
print(read_dictionary["word"])
# Out:
# [-4.3036e-01 -4.0622e-01 -1.8279e-01 -1.2548e-01  4.3490e-02 -2.1216e-01
#  -3.6509e-01  3.2598e-02 -1.0828e-01 -1.3537e+00 -1.9152e-01  1.8976e-01
#  -4.3755e-01  2.4337e-01  2.9676e-01 -4.2886e-02 -4.9444e-02  3.7994e-01
#   5.5679e-02  1.0740e-01 -1.5195e-01  2.7901e-03 -5.0005e-02  1.6948e-01
#  -1.7819e-01 -1.7449e-01  1.8066e-01 -3.5179e-01  4.3839e-01  2.3936e-01
#  -1.2200e-01 -1.3631e-02 -2.7989e-01  4.4950e-01 -6.5760e-01 -7.7317e-02
#   6.9246e-02 -7.7499e-01 -4.3509e-01  1.6177e-01 -9.4878e-02  2.5968e-01
#  -3.6336e-02  2.0131e-01  1.6860e-01 -4.3616e-01 -2.1700e-02  6.6751e-02
#  -3.5336e-01  3.5581e-01  4.3044e-01 -1.2607e-01  9.4664e-01  2.5349e-01
#  -6.7874e-01  1.0727e-01  1.1090e-01 -2.2619e-02  5.4648e-01  6.4194e-01
#   7.1169e-01  4.4902e-02  1.0753e-01  4.5971e-01 -4.1282e-02  2.1160e-01
#   3.2395e-01  1.9663e-01  4.1871e-01  3.7204e-01  4.2732e-02 -1.6376e-01
#  -1.3316e-01  6.7047e-02 -1.2618e-01 -6.9014e-02  1.0433e+00  2.7489e-01
#  -8.0330e-03 -1.7116e-01  4.8991e-02  3.0116e-02 -1.1430e-01 -1.8503e-01
#  -3.2292e-01 -2.3769e-01 -2.2741e-01  4.8045e-01  1.3310e-01  3.0180e-01
#  -8.5152e-01 -1.6602e-01 -4.0593e-01 -4.5165e-01  3.1579e-01  5.4353e-02
#  -3.3901e-01 -1.8843e-01  1.3239e-01 -4.7028e-01  2.9688e-02  2.3830e-01
#   9.4393e-02  2.3215e-01  1.2413e-03 -3.5004e-01  9.0199e-02 -6.1024e-01
#   1.9133e-01  5.3502e-01  2.7979e-01  3.5864e-01 -1.3216e-01  5.2079e-02
